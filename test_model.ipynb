# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, LabelEncoder, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.naive_bayes import GaussianNB
from scipy.stats import probplot
from statistics import mean, stdev
from sklearn.metrics import roc_auc_score, accuracy_score, roc_curve, auc, confusion_matrix, f1_score, classification_report, mean_absolute_error, log_loss
from sklearn.model_selection import KFold, cross_val_score, cross_validate, StratifiedKFold, train_test_split, GridSearchCV
from sklearn.svm import SVC 
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import *
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, ExtraTreesClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression

# %%
import pandas as pd

file_path = 'D:\WorkSpace_Thinh1\FSS\hmeq.csv'
data = pd.read_csv(file_path)

data.head()
# Out:
#    BAD  LOAN  MORTDUE     VALUE   REASON     JOB   YOJ  DEROG  DELINQ  \
# 0    1  1100  25860.0   39025.0  HomeImp   Other  10.5    0.0     0.0
# 1    1  1300  70053.0   68400.0  HomeImp   Other   7.0    0.0     2.0
# 2    1  1500  13500.0   16700.0  HomeImp   Other   4.0    0.0     0.0
# 3    1  1500      NaN       NaN      NaN     NaN   NaN    NaN     NaN
# 4    0  1700  97800.0  112000.0  HomeImp  Office   3.0    0.0     0.0
#
#         CLAGE  NINQ  CLNO  DEBTINC
# 0   94.366667   1.0   9.0      NaN
# 1  121.833333   0.0  14.0      NaN
# 2  149.466667   1.0  10.0      NaN
# 3         NaN   NaN   NaN      NaN
# 4   93.333333   0.0  14.0      NaN

# %%
data_train,data_test = train_test_split(data,test_size=0.2,random_state=0)

# %%
numeric_columns = data_test.select_dtypes(include=['number']).columns

for col in numeric_columns:
    median_value = data_test[col].median()
    data_test[col].fillna(median_value, inplace=True)

missing_values_after_imputation = data_test[numeric_columns].isnull().sum()
missing_values_after_imputation
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_16000\3973881275.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_test[col].fillna(median_value, inplace=True)
# C:\Users\pc\AppData\Local\Temp\ipykernel_16000\3973881275.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_test[col].fillna(median_value, inplace=True)
# C:\Users\pc\AppData\Local\Temp\ipykernel_16000\3973881275.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_test[col].fillna(median_value, inplace=True)
# C:\Users\pc\AppData\Local\Temp\ipykernel_16000\3973881275.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_test[col].fillna(median_value, inplace=True)
# C:\Users\pc\AppData\Local\Temp\ipykernel_16000\3973881275.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_test[col].fillna(median_value, inplace=True)
# C:\Users\pc\AppData\Local\Temp\ipykernel_16000\3973881275.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_test[col].fillna(median_value, inplace=True)
# C:\Users\pc\AppData\Local\Temp\ipykernel_16000\3973881275.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_test[col].fillna(median_value, inplace=True)
# C:\Users\pc\AppData\Local\Temp\ipykernel_16000\3973881275.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_test[col].fillna(median_value, inplace=True)
# C:\Users\pc\AppData\Local\Temp\ipykernel_16000\3973881275.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_test[col].fillna(median_value, inplace=True)
# C:\Users\pc\AppData\Local\Temp\ipykernel_16000\3973881275.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_test[col].fillna(median_value, inplace=True)
# C:\Users\pc\AppData\Local\Temp\ipykernel_16000\3973881275.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_test[col].fillna(median_value, inplace=True)
# BAD        0
# LOAN       0
# MORTDUE    0
# VALUE      0
# YOJ        0
# DEROG      0
# DELINQ     0
# CLAGE      0
# NINQ       0
# CLNO       0
# DEBTINC    0
# dtype: int64

# %%
data_test["REASON"] = data_test["REASON"].fillna("Other reason")
data_test['JOB'] = data_test['JOB'].fillna(data_test['JOB'].mode()[0])

# %%
categorical_columns = data_test.select_dtypes(include=['object']).columns

missing_values_after_imputation_categorical = data_test[categorical_columns].isnull().sum()
missing_values_after_imputation_categorical
# Out:
# REASON    0
# JOB       0
# dtype: int64

# %%
data_test = pd.get_dummies(data_test, columns=['JOB', 'REASON'])
data_test.head()
# Out:
#       BAD   LOAN  MORTDUE     VALUE   YOJ  DEROG  DELINQ       CLAGE  NINQ  \
# 916     1   9000  84532.0  104000.0   3.0    0.0     0.0   50.666667   1.0
# 3338    0  17700  72911.0   97317.0   1.0    0.0     0.0   82.398384   0.0
# 5754    0  43700  66859.0   48535.0   8.0    6.0     0.0   95.719805   1.0
# 4290    0  22400  98238.0  135561.0   8.0    0.0     0.0  194.282099   0.0
# 1540    0  11300  46120.0   52911.0  19.0    0.0     0.0  229.441578   1.0
#
#       CLNO    DEBTINC  JOB_Mgr  JOB_Office  JOB_Other  JOB_ProfExe  JOB_Sales  \
# 916    3.0  34.319763    False       False      False         True      False
# 3338  17.0  25.329251     True       False      False        False      False
# 5754  19.0  26.981183    False       False       True        False      False
# 4290  20.0  29.373607    False       False      False         True      False
# 1540  17.0  36.334814     True       False      False        False      False
#
#       JOB_Self  REASON_DebtCon  REASON_HomeImp  REASON_Other reason
# 916      False            True           False                False
# 3338     False            True           False                False
# 5754     False            True           False                False
# 4290     False            True           False                False
# 1540     False           False            True                False

# %%
y = data_test["BAD"]                  
X = data_test.drop(["BAD"],axis=1)

# %%
import numpy as np

def scale_score(p):
    factor = 25/np.log(2)
    offset = 600 - factor*np.log(50)
    val = (1-p)/p
    score = offset + factor * np.log(val)
    score = score + 150
    return round(max(0, min(score, 850)))

# %%
import numpy as np

def scale_score_normalized(p, p_min=0.01, p_max=0.99):
    factor = 25 / np.log(2)
    offset = 750 - factor * np.log(50)
    
    val =  p / (1-p)
    score = offset + factor * np.log(val)
    
    val_min = (1 - p_min) / p_min
    val_max = (1 - p_max) / p_max
    
    score_min = offset + factor * np.log(val_min)
    score_max = offset + factor * np.log(val_max)
    
    normalized_score = 750 * (score - score_min) / (score_max - score_min)
    
    return round(max(0, min(normalized_score, 750)))

# %%
import joblib

rf_model = joblib.load(r'D:\WorkSpace_Thinh1\FSS\model\best_rf_model.pkl')

# %%
pred_prob_test = rf_model.predict_proba(X)[:,1]
data_test["Prob"] = pred_prob_test
data_test["Score"] = data_test["Prob"].apply(lambda x: scale_score(x))
data_test["BAD"] = y

# %%
data_test["Score"].max()
# Out:
# 850

# %%
data_test["Score"].min()
# Out:
# 498

# %%
data_test.head(20)
# Out:
#       BAD   LOAN   MORTDUE     VALUE   YOJ  DEROG  DELINQ       CLAGE  NINQ  \
# 916     1   9000   84532.0  104000.0   3.0    0.0     0.0   50.666667   1.0
# 3338    0  17700   72911.0   97317.0   1.0    0.0     0.0   82.398384   0.0
# 5754    0  43700   66859.0   48535.0   8.0    6.0     0.0   95.719805   1.0
# 4290    0  22400   98238.0  135561.0   8.0    0.0     0.0  194.282099   0.0
# 1540    0  11300   46120.0   52911.0  19.0    0.0     0.0  229.441578   1.0
# 4441    0  23100   71680.0  101492.0   1.0    0.0     0.0  230.361616   5.0
# 1922    0  12600   49986.0   67896.0   3.0    0.0     0.0  190.159907   1.0
# 5672    0  40400   63131.0  109395.0  14.0    0.0     0.0  198.448419   0.0
# 5195    1  28000   86600.0  127000.0   6.5    0.0     4.0  234.366667   5.0
# 1281    0  10300   57676.0   71027.0  19.0    0.0     0.0  157.519637   1.0
# 5482    1  33200   36705.0   78040.0  19.0    2.0     0.0  120.090143   0.0
# 910     1   9000   52311.0   68994.0   0.0    0.0     1.0  137.784004   0.0
# 4264    0  22200   64809.0   96831.0  17.0    0.0     0.0  639.058172   0.0
# 3397    0  18000   45000.0   68500.0  10.0    0.0     0.0  190.800000   1.0
# 130     1   4700   26900.0   45000.0   9.0    1.0     2.0   90.466667   1.0
# 4220    0  22000   15774.0   60115.0  27.0    0.0     1.0  213.414238   0.0
# 1433    0  10900   25061.0   35792.0   3.0    0.0     0.0  171.992240   1.0
# 5132    0  27600   73846.0  100216.0  12.0    0.0     0.0  282.370661   1.0
# 4641    0  24400  237543.0  261393.0   3.0    1.0     0.0  254.517448   2.0
# 5484    0  33200  119049.0  175867.0  17.0    0.0     0.0  112.467785   0.0
#
#       CLNO  ...  JOB_Office  JOB_Other  JOB_ProfExe  JOB_Sales  JOB_Self  \
# 916    3.0  ...       False      False         True      False     False
# 3338  17.0  ...       False      False        False      False     False
# 5754  19.0  ...       False       True        False      False     False
# 4290  20.0  ...       False      False         True      False     False
# 1540  17.0  ...       False      False        False      False     False
# 4441  24.0  ...       False      False        False      False     False
# 1922  17.0  ...       False      False        False      False     False
# 5672  21.0  ...       False      False        False      False     False
# 5195  35.0  ...       False      False         True      False     False
# 1281  11.0  ...       False       True        False      False     False
# 5482  13.0  ...       False      False        False      False     False
# 910    9.0  ...        True      False        False      False     False
# 4264  24.0  ...       False      False         True      False     False
# 3397  42.0  ...       False      False         True      False     False
# 130   16.0  ...       False      False         True      False     False
# 4220  24.0  ...       False       True        False      False     False
# 1433  20.0  ...       False       True        False      False     False
# 5132  33.0  ...       False      False         True      False     False
# 4641  50.0  ...       False      False        False      False      True
# 5484  16.0  ...       False      False         True      False     False
#
#       REASON_DebtCon  REASON_HomeImp  REASON_Other reason      Prob  Score
# 916             True           False                False  0.718043    575
# 3338            True           False                False  0.011642    769
# 5754            True           False                False  0.010306    774
# 4290            True           False                False  0.004191    806
# 1540           False            True                False  0.014858    760
# 4441            True           False                False  0.018021    753
# 1922            True           False                False  0.005256    798
# 5672            True           False                False  0.004170    806
# 5195            True           False                False  0.721758    575
# 1281            True           False                False  0.024393    742
# 5482            True           False                False  0.918714    521
# 910             True           False                False  0.628272    590
# 4264           False            True                False  0.000604    850
# 3397            True           False                False  0.088282    693
# 130            False            True                False  0.690136    580
# 4220            True           False                False  0.010045    774
# 1433            True           False                False  0.134480    676
# 5132            True           False                False  0.003581    812
# 4641           False            True                False  0.026148    739
# 5484            True           False                False  0.005473    797
#
# [20 rows x 22 columns]

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data_test["Score"], bins=30, kde=True, color='blue')
plt.title('Distribution of Credit Scores')
plt.xlabel('Credit Score')
plt.ylabel('Frequency')

bin_counts, bin_edges, _ = plt.hist(data_test["Score"], bins=30, color='blue', alpha=0.7)

for count, edge in zip(bin_counts, bin_edges[:-1]):
    plt.text(edge + 5, count + 5, f'{int(count)}', fontsize=10, ha='center', va='bottom')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

bad_value_counts = data_test['BAD'].value_counts()

plt.figure(figsize=(8, 6))
ax = bad_value_counts.plot(kind='bar', color='blue')

plt.xlabel('BAD Values')
plt.ylabel('Frequency')
plt.title('Bar Chart of BAD Values')

for index, value in enumerate(bad_value_counts):
    plt.text(index, value + 5, str(value), ha='center', va='bottom', fontsize=10)

plt.show()

# %%
# Define credit score segments
bins = [300, 640, 700, 750, 851]
labels = ['300-639', '640-699', '700-749', '750-850']
data_test['Segment'] = pd.cut(data_test['Score'], bins=bins, labels=labels, right=False)

# Count the number of customers in each segment
segment_counts = data_test['Segment'].value_counts().sort_index()

# Plot the number of customers in each segment
plt.figure(figsize=(10, 6))
sns.barplot(x=segment_counts.index, y=segment_counts.values, palette='viridis')
plt.title('Number of Customers in Each Credit Score Segment')
plt.xlabel('Credit Score Segment')
plt.ylabel('Number of Customers')

# Add counts on top of the bars
for i, count in enumerate(segment_counts.values):
    plt.text(i, count + 5, str(count), ha='center', va='bottom', fontsize=10)

plt.show()

# Calculate average loan amount for each segment
average_loan_by_segment = data_test.groupby('Segment')['LOAN'].median()

# Print the average loan amounts
print(average_loan_by_segment)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_16000\682404919.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=segment_counts.index, y=segment_counts.values, palette='viridis')
# Segment
# 300-639    15000.0
# 640-699    13650.0
# 700-749    15000.0
# 750-850    18050.0
# Name: LOAN, dtype: float64
# C:\Users\pc\AppData\Local\Temp\ipykernel_16000\682404919.py:23: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   average_loan_by_segment = data_test.groupby('Segment')['LOAN'].median()

# %%
# Define credit score segments
bins = [300, 640, 700, 750, 851]
labels = ['300-639', '640-699', '700-749', '750-850']
data_test['Segment'] = pd.cut(data_test['Score'], bins=bins, labels=labels, right=False)

# Plot KDE for each segment
plt.figure(figsize=(12, 8))
for label in labels:
    subset = data_test[data_test['Segment'] == label]
    sns.kdeplot(subset['LOAN'], label=label, fill=True)

plt.title('Distribution of Loan Amounts by Credit Score Segment')
plt.xlabel('Loan Amount')
plt.ylabel('Density')
plt.legend(title='Credit Score Segment')
plt.show()

# Plot Box Plot for each segment
plt.figure(figsize=(12, 8))
sns.boxplot(x='Segment', y='LOAN', data=data_test, palette='viridis')
plt.title('Box Plot of Loan Amounts by Credit Score Segment')
plt.xlabel('Credit Score Segment')
plt.ylabel('Loan Amount')
plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_16000\3240129667.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Segment', y='LOAN', data=data_test, palette='viridis')
